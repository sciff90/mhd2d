# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = '../fortran/data/run_parameters.dat'
f = open ( filename , 'rb' )

# %%
#Cordinate Definitions
num_u1 = np.fromfile ( f , dtype = np.int32 , count = 1 )[0]
num_u3 = np.fromfile ( f , dtype = np.int32 , count = 1 )[0]

#Grid Arrays
x_arr = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
y_arr = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
z_arr = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
r_arr = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )

#U Arrays
u1 = np.fromfile ( f , dtype = np.float64 , count = num_u1 )
u3 = np.fromfile ( f , dtype = np.float64 , count = num_u3 )

#g arrays
g11 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
g22 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
g33 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
g13 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
gsup13 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
gsup11 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
gsup22 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
gsup33 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
costh = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
dmudx = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )

#Scaling Arrays
h1 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
h2 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
h3 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
h30 = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
Jac = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )

#courant numbers
dt = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
nt = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]

#Va Arrays
va_arr = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
rho_a = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )

#Run Paramaters
m = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
r_iono = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
cour = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
dtplot = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
drive0 = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
Phi = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
Freq = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
z0= np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
ds0 = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
dsn = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]
modefrac = np.fromfile ( f , dtype = np.float64 , count = 1 )[0]


#Atmospheric Arrays
eta_arr = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
sigpatm_N = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
sighatm_N = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
sig0atm_N = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
sigpatm_S = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
sighatm_S = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )
sig0atm_S = np.fromfile ( f , dtype = np.float64 , count = num_u1*num_u3 )

# %%
f.close()

# %%
#Reshape arrays to 2D
#'F' means they're fortran refernced(Column Major)
va_arr = np.reshape(va_arr,(num_u1,num_u3),order='F')

x_arr = np.reshape(x_arr,(num_u1,num_u3),order='F')
y_arr = np.reshape(y_arr,(num_u1,num_u3),order='F')
r_arr = np.reshape(r_arr,(num_u1,num_u3),order='F')

g11 = np.reshape(g11,(num_u1,num_u3),order='F')
g22 = np.reshape(g22,(num_u1,num_u3),order='F')
g33 = np.reshape(g33,(num_u1,num_u3),order='F')
g13 = np.reshape(g13,(num_u1,num_u3),order='F')
gsup13 = np.reshape(gsup13,(num_u1,num_u3),order='F')
gsup11 = np.reshape(gsup11,(num_u1,num_u3),order='F')
gsup22 = np.reshape(gsup22,(num_u1,num_u3),order='F')
gsup33 = np.reshape(gsup33,(num_u1,num_u3),order='F')
costh = np.reshape(costh,(num_u1,num_u3),order='F')
Jac = np.reshape(Jac,(num_u1,num_u3),order='F')
dmudx = np.reshape(dmudx,(num_u1,num_u3),order='F')

# %%
print 'Num_u1:',num_u1
print 'Num_u3:',num_u3
# Out:
# Num_u1: 151
# Num_u3: 371

# %%
#define default figure size
pylab.rcParams['figure.figsize'] = (20, 16)

#plot the grid
plot(x_arr,y_arr,'ro',ms=4);

# %%
pylab.rcParams['figure.figsize'] = (11.7*2, 8.3*2)
x_arr = np.reshape(x_arr,(num_u1*num_u3),order='F')
y_arr = np.reshape(y_arr,(num_u1*num_u3),order='F')
va_arr = np.reshape(va_arr,(num_u1*num_u3),order='F')
xi = linspace(x_arr.min(), x_arr.max(),1000)
yi = linspace(y_arr.min(), y_arr.max(),1000)
#zi = scipy.interpolate.griddata((x_arr, y_arr), log(va), (xi, yi), method='cubic')
zi = griddata(x_arr, y_arr, log(va_arr), xi, yi)
contourf(xi, yi, zi,200);
#to change colormap cmap=cm.xxx
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xd027248>

# %%
x_arr = np.reshape(x_arr,(num_u1,num_u3),order='F')
y_arr = np.reshape(y_arr,(num_u1,num_u3),order='F')
va_arr = np.reshape(va_arr,(num_u1,num_u3),order='F')
pcolormesh(x_arr,y_arr,log(va_arr),shading='flat')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xe50ce60>

# %%
pcolormesh(x_arr,y_arr,log(va_arr),shading='gouraud')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa432cf8>

# %%
def plot_sub(row,col,xarr,yarr,title,ax_arr,plot_opts):
    ax_arr[row, col].plot(xarr,yarr,plot_opts)
    ax_arr[row, col].text(0.5, 1.08, title,
         horizontalalignment='center',
         fontsize=20,
         transform = ax_arr[row,col].transAxes)
    ax_arr[row,col].set_xlim([np.min(xarr), np.max(xarr)])
    
    
#plot grid parameters
Lval=6.0
Lidx =  min(np.where(r_arr[:,num_u3/2]>=Lval)[0])
pylab.rcParams['figure.figsize'] = (20, 12)

# Four axes, returned as a 2-d array
f, axarr = plt.subplots(3, 4)

plot_sub(0,0,u3,gsup11[Lidx,:],r'$g_{11_{con}}$',axarr,'-b')
plot_sub(0,1,u3,gsup22[Lidx,:],r'$g_{22_{con}}$',axarr,'-b')
plot_sub(0,2,u3,gsup33[Lidx,:]*dmudx[Lidx,:]**2,r'$g_{33_{con}}$',axarr,'-b')
plot_sub(0,3,u3,gsup13[Lidx,:]*dmudx[Lidx,:],r'$g_{13_{con}}$',axarr,'-b')

plot_sub(1,0,u3,g11[Lidx,:],r'$g_{11_{cov}}$',axarr,'-b')
plot_sub(1,1,u3,g22[Lidx,:],r'$g_{22_{cov}}$',axarr,'-b')
plot_sub(1,2,u3,g33[Lidx,:]/dmudx[Lidx,:]**2,r'$g_{33_{cov}}$',axarr,'-b')
plot_sub(1,3,u3,g13[Lidx,:]/dmudx[Lidx,:],r'$g_{13_{cov}}$',axarr,'-b')

plot_sub(2,0,u3,Jac[Lidx,:]/dmudx[Lidx,:],r'$Jacobian$',axarr,'-b')
plot_sub(2,1,u3,r_arr[Lidx,:],r'$R_{arr}$',axarr,'-b')
plot_sub(2,2,u3,arccos(costh[Lidx,:])*180/pi,r'$\theta_{arr}$',axarr,'-b')

axarr[2, 3].plot(x_arr,y_arr,'og',ms=0.3)
axarr[2, 3].text(  0.5, 1.08, r'$Grid$',
                        horizontalalignment='center',
                        fontsize=20,
                        transform = axarr[2,3].transAxes)
axarr[2,3].set_xlim([0, 10])

axarr[2, 3].plot(x_arr[Lidx,:],y_arr[Lidx,:],'-r')
axarr[2, 3].text(  0.5, 1.08, r'$Grid$',
                        horizontalalignment='center',
                        fontsize=20,
                        transform = axarr[2,3].transAxes)
    
subplots_adjust(left=0.05, bottom=0.05, right=0.95, top=0.95, wspace=0.25, hspace=0.25)
f.savefig('../fortran/plots/test.pdf',format='PDF')
